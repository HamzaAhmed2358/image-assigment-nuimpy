# %%
import numpy as np
from PIL import Image
import os 
import matplotlib.pylab as plt
rootDir = r'C:\Users\hamza\Pictures\photos'
for dirName, subdirList, fileList in os.walk(rootDir):
    print('found directory: %s' % dirName)
    for fname in fileList:
        print('/t%s'% fname)
        name = fname
        print(name)

        img = Image.open(r'C:\Users\hamza\Desktop\Assignment\imag.jpg')
        img.load()
        data = np.asarray( img, dtype="int32" )
        mainarray = data[:200, :200, :3] 
        print(mainarray)
        
        plt.imshow(mainarray)
# Out:
# found directory: C:\Users\hamza\Pictures\photos
# /timag.jpg
# imag.jpg
# [[[ 26 100 199]
#   [ 24  98 197]
#   [ 23  95 193]
#   ...
#   [  1   8  24]
#   [  0   9  26]
#   [  0   9  27]]
#
#  [[ 27 101 200]
#   [ 25  99 198]
#   [ 23  95 193]
#   ...
#   [  1   8  24]
#   [  0   9  26]
#   [  0   9  27]]
#
#  [[ 26 101 202]
#   [ 25 100 201]
#   [ 24  98 197]
#   ...
#   [  1   8  24]
#   [  0   9  26]
#   [  0   9  27]]
#
#  ...
#
#  [[ 82  68  55]
#   [ 69  55  42]
#   [ 69  55  42]
#   ...
#   [  6   6   6]
#   [  9   9   9]
#   [ 13  13  13]]
#
#  [[ 51  35  20]
#   [ 38  25   9]
#   [ 36  23   7]
#   ...
#   [  6   6   6]
#   [  8   8   8]
#   [ 13  13  13]]
#
#  [[ 71  55  40]
#   [ 71  55  40]
#   [ 79  63  48]
#   ...
#   [  6   6   6]
#   [  8   8   8]
#   [ 13  13  13]]]
